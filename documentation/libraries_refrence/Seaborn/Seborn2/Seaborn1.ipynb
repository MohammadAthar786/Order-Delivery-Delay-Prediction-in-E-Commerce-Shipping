# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\mohda\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\mohda\anaconda3\lib\site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=0.25 in c:\users\mohda\anaconda3\lib\site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\mohda\anaconda3\lib\site-packages (from seaborn) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mohda\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\mohda\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mohda\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mohda\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\mohda\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mohda\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\mohda\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mohda\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mohda\anaconda3\lib\site-packages (from pandas>=0.25->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\mohda\anaconda3\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\mohda\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# import and load dataset
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.histplot(data=tips, x="total_bill")
plt.show()

# %% [markdown]
# # Distribution Plots (Univariate Analysis)
# ##  Analyze distribution of one variable.
# # 📊 Plots to Learn:
# | Plot         | Use Case                 |
# | ------------ | ------------------------ |
# | `histplot()` | Histogram                |
# | `kdeplot()`  | Kernel Density Estimate  |
# | `displot()`  | Combo of histogram + KDE |
# | `rugplot()`  | Distribution markers     |

# %%
sns.histplot(tips["total_bill"], kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.kdeplot(tips["tip"], shade=True)
# Out:
# C:\Users\mohda\AppData\Local\Temp\ipykernel_20728\1540267782.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(tips["tip"], shade=True)
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.displot(data=tips, x="total_bill", col="sex")
# Out:
# c:\Users\mohda\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Bar Plot
# ✅ Purpose:
# Show mean (or estimator) of numeric variable across categories.
# ```
# 🔧 Syntax: sns.barplot(x=None, y=None, data=None, estimator=np.mean, ci=95,.......)
# ```
# | Parameter   | Description                                                         |
# | ----------- | ------------------------------------------------------------------- |
# | `x`         | Categorical variable (grouping axis)                                |
# | `y`         | Numerical variable (height of bars)                                 |
# | `data`      | DataFrame containing the variables                                  |
# | `estimator` | Function used to aggregate data (default: `np.mean`)                |
# | `ci`        | Size of confidence interval (default: 95). Use `ci=None` to remove. |
# | `palette`   | Color palette (e.g., `"Blues"`, `["red", "blue"]`, or `hue`-based)  |
# | `hue`       | Additional categorical variable for subgroups (side-by-side bars)   |
# | `order`     | Custom order of categories                                          |
# | `capsize`   | Adds caps to error bars                                             |
# | `errcolor`  | Color of the error bars                                             |
# | `linewidth` | Width of the bar borders                                            |
#
#
#
# 🧠 Interpretation:
#
# Height of bar = average value.(if used default np.mean)
#
# Error bars = confidence interval.

# %%
# default use case
sns.barplot(x="sex", y="tip", data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
# CUSTOMIZATION 
# Change Aggregation with Different Function
import numpy as np
# Show the sum of total_bill by day
sns.barplot(x="day", y="total_bill", data=tips, estimator=np.sum)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# changing orientation
sns.barplot(x="total_bill", y="day", data=tips, orient="h")
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
# Adding hue -categorized distribution 
sns.barplot(x="day", y="total_bill", hue="sex", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Box plot
# #### Used to show distribution, central tendency, and spread of a numerical variable, often grouped by categories.
# ```
# sns.boxplot(x=None, y=None, data=None, hue=None, ...)
# ```
# | Parameter   | Description                                    |
# | ----------- | ---------------------------------------------- |
# | `x`         | Categorical variable (used for grouping)       |
# | `y`         | Numerical variable (used for plotting boxplot) |
# | `data`      | DataFrame containing the variables             |
# | `hue`       | Subgrouping within each category               |
# | `order`     | Custom order of categories                     |
# | `palette`   | Color scheme                                   |
# | `orient`    | Orientation: `'v'` or `'h'`                    |
# | `width`     | Width of box (default is 0.8)                  |
# | `fliersize` | Size of outlier points                         |
# | `linewidth` | Width of box and whisker lines                 |
# | `notch`     | If True, draw notched box                      |
#
# ### Each box represents:
#
# Median (middle line in box)
#
# Q1–Q3 (Interquartile Range, IQR) — the box itself
#
# Whiskers — extend to 1.5 × IQR
#
# Outliers — dots outside whiskers
#
# ### 🔍 4. Interpretation
# Taller boxes → more spread in data.
#
# Outliers → dots beyond whiskers.
#
# Position of the median line inside the box shows skewness:
#
# Near top → left-skewed
#
# Near bottom → right-skewed

# %%
# Basic Example 
sns.boxplot(x="day", y="total_bill", data=tips)

plt.title("Total Bill Distribution by Day")
plt.show()

# %%
# 🎨 CUSTOMIZATION
##🔸 Add hue for subgroups (e.g., gender within day)
sns.boxplot(x="day", y="total_bill", hue="sex", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# 🔸 Horizontal Boxplot
sns.boxplot(x="total_bill", y="day", data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
# 🔸 Remove outliers
sns.boxplot(x="day", y="total_bill", data=tips, showfliers=False)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# 🔸 Notched Box (shows confidence interval around median)
sns.boxplot(x="day", y="total_bill", data=tips, notch=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# 🔸 Use palette
sns.boxplot(x="day", y="total_bill", data=tips, palette="Set2")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Violin Plot
# ➤ Used to show the distribution, probability density, central tendency, and spread of a numerical variable across categories.
# ```
# 🔧 1. Basic Syntax:sns.violinplot(x=None, y=None, data=None, hue=None, ...)
# ```
# | Parameter | Description                                                              |
# | --------- | ------------------------------------------------------------------------ |
# | `x`       | Categorical variable (used for grouping)                                 |
# | `y`       | Numerical variable (used for plotting)                                   |
# | `data`    | DataFrame containing variables                                           |
# | `hue`     | Subgrouping within each category                                         |
# | `split`   | If `hue` is used, `split=True` puts both violins side-by-side inside one |
# | `inner`   | What to draw inside (e.g., `'box'`, `'quartile'`, `'point'`, `None`)     |
# | `bw`      | Bandwidth of KDE (smoothing). Lower = more jagged.                       |
# | `scale`   | How the violin width is scaled: `'area'`, `'count'`, `'width'`           |
# | `palette` | Color palette                                                            |
# | `cut`     | Extends KDE beyond extreme data points (default: `2`)                    |
#
# ### 🔍 4. Interpretation
# Width of the violin: Indicates density (how many points fall there)
#
# Thicker areas: More observations
#
# Thin ends: Fewer data points
#
# White dot: Median (default when inner="box")
#
# Box inside violin: Interquartile range
#
# Lines inside: Quartiles (when inner='quartile')

# %%
# Basic Example
sns.violinplot(x="smoker", y="tip", data=tips)
# Out:
# <Axes: xlabel='smoker', ylabel='tip'>

# %%
# 🎨 5. CUSTOMIZATION
##🔸 Add Hue (with optional split)
sns.violinplot(x="day", y="total_bill", hue="sex", data=tips, split=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#  Draw only quartile lines inside
sns.violinplot(x="day", y="total_bill", data=tips, inner="quartile")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# 🔸 Remove all inner markings
sns.violinplot(x="day", y="total_bill", data=tips, inner=None)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# 🔸 Show individual points using swarmplot
sns.violinplot(x="day", y="total_bill", data=tips, inner=None)
sns.swarmplot(x="day", y="total_bill", data=tips, color="k", alpha=0.5)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# Change of scale 
sns.violinplot(x="day", y="total_bill", data=tips, scale="count")  # Width ∝ sample size
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Count Plot
# ✅ Purpose:
#
# ➤ Used to show the number of observations in each category of a categorical feature.
#  showing counts of each category (like histogram for categorical data).
#
# ```
# sns.countplot(x=None, y=None, data=None, hue=None, ...)
#
# ```
# | Parameter    | Description                                                   |
# | ------------ | ------------------------------------------------------------- |
# | `x` / `y`    | Categorical variable (x = vertical bars, y = horizontal bars) |
# | `data`       | DataFrame                                                     |
# | `hue`        | Subgrouping by another categorical column                     |
# | `order`      | Custom order of categories                                    |
# | `palette`    | Colors                                                        |
# | `orient`     | `'v'` (default) or `'h'`                                      |
# | `saturation` | Transparency of bars (0 → transparent, 1 → solid)             |
# | `linewidth`  | Thickness of bar borders                                      |

# %%
# Basic Example 
sns.countplot(x="day", data=tips)
plt.title("Number of Records per Day")
plt.show()

# %%
# 🎨 4. Customizations
# 🔸 Add Hue (subgroup by gender, for example)
sns.countplot(x="day", hue="sex", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
# 🔸 Horizontal Bars
sns.countplot(y="day", data=tips)
# Out:
# <Axes: xlabel='count', ylabel='day'>

# %%
# 🔸 Custom Order
sns.countplot(x="day", data=tips, order=["Thur", "sat", "sun", "friday"])
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
# 🔸 Change Color Palette
sns.countplot(x="day", data=tips, palette="Set2")
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
# 🔸 Add Counts as Labels 
ax = sns.countplot(x="day", data=tips)
for p in ax.patches:
    ax.annotate(f"{p.get_height()}", (p.get_x() + 0.3, p.get_height() + 1))

# %% [markdown]
# # ✅ Step 4: Bivariate & Relationship Plots
# ## 🎯 Goal:
# ### Explore relation between two numeric features.
#
# #### 📊 Plots:
# | Plot            | Use                               |
# | --------------- | --------------------------------- |
# | `scatterplot()` | 2D relation                       |
# | `lineplot()`    | Trend lines                       |
# | `regplot()`     | Scatter + regression              |
# | `lmplot()`      | Multiple linear plots by category |
# | `relplot()`     | Faceted version of scatter/line   |

# %% [markdown]
# # ScatterPlot
# ### All you must know about it
# ### Shows relationship between two numeric variables.
# ```
# sns.scatterplot(x=None, y=None, data=None, hue=None, style=None, size=None)
# ```
#
#
# 🔸 Key Arguments:
#
# | Argument | Use                        |
# | -------- | -------------------------- |
# | `x`, `y` | Column names for axes      |
# | `data`   | DataFrame                  |
# | `hue`    | Color grouping             |
# | `style`  | Point style (e.g. markers) |
# | `size`   | Point size                 |
#
# 🧠 Interpretation:\
# Each point = one observation. Useful to see trends, clusters, outliers.

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips, hue="sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## sns.lineplot()
# ### ✅ Purpose:
#
# Shows trends across an ordered variable (time or sequence).
# ```
# 🔧 Syntax: sns.lineplot(x=None, y=None, data=None, hue=None, style=None)
# ```

# %%
sns.lineplot(x="size", y="tip", data=tips)

# x="size": Number of people in the party (table size)
# y="tip": Dollar amount of the tip given for the meal
# data=tips: Uses the built-in "tips" dataset, which records information about tips received by a restaurant’s waitstaff.
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %%
## INTERPRETATION : 

# The relationship is mostly positive: bigger party → bigger tip.
# The growth in tip amount levels off around 4–5 people, illustrating a plateau.
# There's more variation in tips as party size gets larger, suggesting diverse tipping behaviors among bigger groups.

# %%
sns.regplot(x="total_bill", y="tip", data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # ✅ Step 5: Multivariate Plots
# ## 🎯 Goal:
# ### Visualize how more than 2 features interact.
#
# #### 📊 Plots:
# | Plot          | Use                            |
# | ------------- | ------------------------------ |
# | `pairplot()`  | Grid of pairwise scatter plots |
# | `jointplot()` | 2D + distribution              |
# | `heatmap()`   | Correlation matrix             |

# %%
sns.pairplot(tips, hue="sex")
# Out:
# c:\Users\mohda\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="hex")

# %%
numeric_tips = tips.select_dtypes(include="number")

sns.heatmap(numeric_tips.corr(),annot=True, cmap="coolwarm")
plt.title("Correlation Matrix of Numeric Features in Tips Dataset")
plt.show()
# agar dataset jo pass kar rahe ho usme categorical colimns bhi hai toh , kaam nahi karega jaise pehle main pass kara tha tips.corr(), (toh woh kam nahi
# kiya tha kyunki tips dataset me originally categorical columns bhi the ,isliye mene ek dataset only numerical coumns ka banaya uska correlation matrix
# pass kiya heatmap main , jaise ki dikh bhi raha hai)

# %% [markdown]
# ✅ Step 6: Advanced Customization & Themes
#
# 🎯 Goal:\
# Make your plots publication-quality.
#
# 🧰 Tools:\
# sns.set_style("whitegrid")
#
# palette="coolwarm" or custom palettes
#
# context='talk' for larger fonts
#
# hue, size, style for aesthetics
#
# Axis labels, legends, titles

# %%
sns.set_style("ticks")
sns.set_context("talk")
sns.boxplot(x="day", y="total_bill", data=tips, palette="coolwarm")
plt.title("Total Bill by Day")
# Out:
# Text(0.5, 1.0, 'Total Bill by Day')

# %% [markdown]
# # ✅ Step 7: Working with Subplots / Facets
# ## 🎯 Goal:
# ### Plot multiple plots by subcategories.
#
# #### 📊 Tools:
#  FacetGrid()
#
#  catplot()
#
#  relplot()
#
#  PairGrid()

# %%
g = sns.FacetGrid(tips, col="sex", row="smoker")
g.map(sns.histplot, "total_bill")

sns.catplot(x="day", y="total_bill", kind="violin", col="sex", data=tips)
# Out:
# c:\Users\mohda\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\mohda\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
